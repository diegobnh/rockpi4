# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Load in the data

# %%
def drop_constant_column_v2(df):
        
        drop_col = [str(i) for i in range(len(df.columns)) if df[df.keys()[i]].nunique() == 1]
        df.drop(drop_col, axis=1, inplace=True)
        
        return drop_col

# %%
labeled_dataset_dir = 'Summer_Datasets/2b_median_dataset.csv'
unlabeled_dataset_dir = 'Summer_Datasets/2b_dataset.csv'

df_unlab = pd.read_csv(unlabeled_dataset_dir)
df_lab = pd.read_csv(labeled_dataset_dir)

#Relabel columns so that they are easier to work with
df_lab.columns = [str(i) for i in range(len(df_lab.columns))]
df_unlab.columns = [str(i) for i in range(len(df_unlab.columns))]

# Whe should sure that both dataset has the same valid values (no zero) for each column
# First we remove all the invalid column and remove the same column in the other
drop_col = drop_constant_column_v2(df_lab)
df_unlab.drop(drop_col, axis=1, inplace=True)

# Here we do the oposite
drop_col = drop_constant_column_v2(df_unlab)
df_lab.drop(drop_col, axis=0, inplace=True)

# %% [markdown]
# ### Define Constants

# %%
MAX_PMCS_TO_SELECT = 6  # this is the limit of our architecture
NUM_TARGETS = 2   # this is the number of things we are trying to predict, assumed the last N columns of df_lab

# %% [markdown]
# #### These are the targets for regression and the column names from the labeled dataset

# %%
target_col_names = list(df_lab.columns.values)[-NUM_TARGETS:]
targets = df_lab[target_col_names]

# %% [markdown]
# ### Find how correlated each feature is with the target(s) using spearman, pearson, and kendall

# %%
#Parameters are the labeled dataset (pandas dataframe) and the method of correlation (string)
#To make selection easier, the average correlation between the labels will be the measure of "goodness"

#Returns dataframe with one column labels as '0' where the row numbers correspond to the columns of the labeled dataset
#        This one column dataframe is in sorted order of average correlation with the target(s)

def get_features_correlated_with_target_sorted(df_lab, method):
        
        df = df_lab.copy()
        
        #df.drop(['0'], axis=1, inplace=True)
        #last_column_name = list(df.columns.values)[-2:]
        correlation_matriz = df.corr(method)
        
        dic_params = {}
        for col in target_col_names:
            dic_params[col] = list(abs(correlation_matriz[target_col_names]).drop(target_col_names)[col])
            dic_params[col] = pd.DataFrame({col: dic_params[col]}, index=df.columns[:-NUM_TARGETS])

        ####################################################
        #Find average correlation with each target
        avg_dic_params = {}
        for key, value in dic_params.items():
            for pmc, corr in value.iterrows():
                
                corr = list(corr)[0]

                if pmc not in list(avg_dic_params.keys()):
                    avg_dic_params[pmc] = corr
                else:
                    avg_dic_params[pmc] = avg_dic_params[pmc] + corr

        for key in list(avg_dic_params.keys()):
            avg_dic_params[key] = avg_dic_params[key]/NUM_TARGETS

        avg_dic_params = pd.DataFrame(avg_dic_params, index=['Average Correlation']).T
        avg_dic_params = avg_dic_params.sort_values('Average Correlation', ascending=False)

        ####################################################

        return avg_dic_params

# %%
correlations = {}

#Put the dataframes in a list to preserve the row labels
correlations['spearman'] = [get_features_correlated_with_target_sorted(df_lab, 'spearman')]
correlations['pearson'] = [get_features_correlated_with_target_sorted(df_lab, 'pearson')]
correlations['kendall'] = [get_features_correlated_with_target_sorted(df_lab, 'kendall')]

# %% [markdown]
# ### Lets visualize the average correlations and Cross Correlation

# %% [markdown]
# #### Spearman

# %%
spear_corr = correlations['spearman'][0].head(15)
plt = spear_corr.plot.bar(rot=0)

# %%
spear_cross_corr = df_lab[spear_corr.T.columns].corr()
spear_cross_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col1,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col2,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row3_col3,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4_col4,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row5_col5,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row6_col6,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col7,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row8_col8,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row9_col9,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row12_col12,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row13_col13,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col1,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col13,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row14_col10{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col2,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col4,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col14,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row6_col14,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row14_col2,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row14_col6{
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col3,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col3{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col5,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4_col8,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row6_col8{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col6,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4_col6,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row6_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row6_col4,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row8_col13,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col12,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row12_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row13_col8{
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col7,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col2{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col8,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row6_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row14_col8{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col9,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col14,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row3_col2,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row12_col5{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col12,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col5,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row5_col1,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row12_col0{
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col13,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row14_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row0_col14,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row3_col5,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row5_col3,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col7,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row14_col0{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col9,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row12_col3{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col3,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col7,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row3_col1,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4_col7,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col2,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col4{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col4{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col6,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row5_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row8_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row13_col2,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row13_col7{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col7,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row11_col9{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col8,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row8_col1{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col9{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row9_col4{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row3_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row8_col7{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col12{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row1_col13,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row13_col9{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col1,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col3,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col5,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col8,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col13,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4_col10,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col1,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col3,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col8,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row7_col13,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col0,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col2,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col4,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col6,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col7,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col9,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col12,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row10_col14,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row12_col10{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col4,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row2_col12,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4_col11,#T_33fc9625_21e5_11eb_a4b8_0c7a1558c077row4

# %%
spear_corr = correlations['spearman'][0]
spear_cross_corr = df_lab[spear_corr.T.columns].corr()

# %% [markdown]
# #### Pearson

# %%
pear_corr = correlations['pearson'][0].head(15)
plt = pear_corr.plot.bar(rot=0)

# %%
pear_cross_corr = df_lab[pear_corr.T.columns].corr()
pear_cross_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row4_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row5_col5,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col6,#T_3419c017_21e5_11eb_a228_0c7a1558c077row7_col7,#T_3419c017_21e5_11eb_a228_0c7a1558c077row8_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row9_col9,#T_3419c017_21e5_11eb_a228_0c7a1558c077row10_col10,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col11,#T_3419c017_21e5_11eb_a228_0c7a1558c077row12_col12,#T_3419c017_21e5_11eb_a228_0c7a1558c077row13_col13,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row4_col6,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col9{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row4_col3{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row4_col0{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col5{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col6,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col6,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row8_col10,#T_3419c017_21e5_11eb_a228_0c7a1558c077row9_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row10_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row10_col9{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col7,#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col9,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col9,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col10,#T_3419c017_21e5_11eb_a228_0c7a1558c077row7_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row7_col5,#T_3419c017_21e5_11eb_a228_0c7a1558c077row8_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row8_col4{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col10{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col11,#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col13,#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col13,#T_3419c017_21e5_11eb_a228_0c7a1558c077row7_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row8_col1{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row0_col12,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col11,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col13,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row4_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row10_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row10_col4{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row7_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row8_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row9_col13,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col12{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col6,#T_3419c017_21e5_11eb_a228_0c7a1558c077row7_col10{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col5,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col5,#T_3419c017_21e5_11eb_a228_0c7a1558c077row5_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row5_col2{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col6{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col7,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col9,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col10,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col11,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col12,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col13,#T_3419c017_21e5_11eb_a228_0c7a1558c077row1_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col11,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col12,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col13,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row5_col12,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col5,#T_3419c017_21e5_11eb_a228_0c7a1558c077row11_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col7,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col9,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col4,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col5,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col6{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row2_col10,#T_3419c017_21e5_11eb_a228_0c7a1558c077row5_col7,#T_3419c017_21e5_11eb_a228_0c7a1558c077row5_col10,#T_3419c017_21e5_11eb_a228_0c7a1558c077row13_col5{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row6_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row9_col10,#T_3419c017_21e5_11eb_a228_0c7a1558c077row12_col14,#T_3419c017_21e5_11eb_a228_0c7a1558c077row14_col9{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col5{
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col7,#T_3419c017_21e5_11eb_a228_0c7a1558c077row3_col9,#T_3419c017_21e5_11eb_a228_0c7a1558c077row4_col8,#T_3419c017_21e5_11eb_a228_0c7a1558c077row4_col9,#T_3419c017_21e5_11eb_a228_0c7a1558c077row8_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row9_col1,#T_3419c017_21e5_11eb_a228_0c7a1558c077row9_col2,#T_3419c017_21e5_11eb_a228_0c7a1558c077row10_col0,#T_3419c017_21e5_11eb_a228_0c7a1558c077row12_col3,#T_3419c017_21e5_11eb_a228_0c7a1558c077row12_col4{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_34

# %%
pear_corr = correlations['pearson'][0]
pear_cross_corr = df_lab[pear_corr.T.columns].corr()

# %% [markdown]
# #### Kendall

# %%
ken_corr = correlations['kendall'][0].head(15)
plt = ken_corr.plot.bar(rot=0)

# %%
ken_cross_corr = df_lab[ken_corr.T.columns].corr()
ken_cross_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col0,#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col1,#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col2,#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col3,#T_34369895_21e5_11eb_9f65_0c7a1558c077row4_col4,#T_34369895_21e5_11eb_9f65_0c7a1558c077row5_col5,#T_34369895_21e5_11eb_9f65_0c7a1558c077row6_col6,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col7,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col8,#T_34369895_21e5_11eb_9f65_0c7a1558c077row9_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row10_col10,#T_34369895_21e5_11eb_9f65_0c7a1558c077row11_col11,#T_34369895_21e5_11eb_9f65_0c7a1558c077row12_col12,#T_34369895_21e5_11eb_9f65_0c7a1558c077row13_col13,#T_34369895_21e5_11eb_9f65_0c7a1558c077row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col1,#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col0,#T_34369895_21e5_11eb_9f65_0c7a1558c077row5_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row9_col5{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col2,#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col0,#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col8,#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col3,#T_34369895_21e5_11eb_9f65_0c7a1558c077row9_col3{
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col3,#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col5,#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col0,#T_34369895_21e5_11eb_9f65_0c7a1558c077row5_col2,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col10,#T_34369895_21e5_11eb_9f65_0c7a1558c077row10_col8{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col4,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col14{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col5,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col10{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col6,#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col8,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col13,#T_34369895_21e5_11eb_9f65_0c7a1558c077row9_col7{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col7{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col8,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col13,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col2,#T_34369895_21e5_11eb_9f65_0c7a1558c077row10_col0,#T_34369895_21e5_11eb_9f65_0c7a1558c077row10_col7,#T_34369895_21e5_11eb_9f65_0c7a1558c077row13_col7,#T_34369895_21e5_11eb_9f65_0c7a1558c077row13_col8{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col2,#T_34369895_21e5_11eb_9f65_0c7a1558c077row13_col5{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col10,#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col8,#T_34369895_21e5_11eb_9f65_0c7a1558c077row6_col7,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col1{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col11{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col12{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col13{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row0_col14{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col2,#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col1,#T_34369895_21e5_11eb_9f65_0c7a1558c077row6_col9{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col3,#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col5,#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col10,#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col1,#T_34369895_21e5_11eb_9f65_0c7a1558c077row5_col0,#T_34369895_21e5_11eb_9f65_0c7a1558c077row10_col1{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col4,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col11{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col6,#T_34369895_21e5_11eb_9f65_0c7a1558c077row6_col1,#T_34369895_21e5_11eb_9f65_0c7a1558c077row9_col2{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col7{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col11,#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col11,#T_34369895_21e5_11eb_9f65_0c7a1558c077row9_col12{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col12,#T_34369895_21e5_11eb_9f65_0c7a1558c077row11_col7{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col13{
#             background-color:  #f29274;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row1_col14,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col14{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col3,#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col2,#T_34369895_21e5_11eb_9f65_0c7a1558c077row5_col1,#T_34369895_21e5_11eb_9f65_0c7a1558c077row7_col5,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row9_col8{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col4{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col6,#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col10{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col7,#T_34369895_21e5_11eb_9f65_0c7a1558c077row5_col13,#T_34369895_21e5_11eb_9f65_0c7a1558c077row13_col0{
#             background-color:  #e8765c;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col9,#T_34369895_21e5_11eb_9f65_0c7a1558c077row6_col8,#T_34369895_21e5_11eb_9f65_0c7a1558c077row8_col6{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col11,#T_34369895_21e5_11eb_9f65_0c7a1558c077row5_col12,#T_34369895_21e5_11eb_9f65_0c7a1558c077row6_col12{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col12,#T_34369895_21e5_11eb_9f65_0c7a1558c077row14_col9{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col13{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row2_col14{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_34369895_21e5_11eb_9f65_0c7a1558c077row3_col4,#T_34369895_21e5_11eb_9f65_0c7a1558c077row13_col14{
#             background-color:  #89acfd;
#             color:  #000000;

# %%
ken_corr = correlations['kendall'][0]
ken_cross_corr = df_lab[ken_corr.T.columns].corr()

# %% [markdown]
# ### Select the best PMCs
# #### Method:
# ##### Select a set of (MAX_PMCS_TO_SELECT) that have the highest average correlation with the target(s) and lowest cross correlation with each other

# %%
# Any pmc whose average correlation with the target(s) is less that this percentage of the maximum average correlation 
#   will not be included in the set of best PMCs
CORRELATION_THRESHOLD_PERCENTAGE = 0.75 

# Any pmc with an absolute correlation, with any other pmc already selected, greater than this will be 
#   considered highly correlated and will not be included in the set of best PMCs
CROSS_CORR_THRESHOLD = 0.5

# %%
#This is not meant to produce a set of pmcs that will generate the best accuracy with an ML model.
#This is meant to produce a set of pmcs that can be reasonably used to model the data.

#The idea being that this function is called, then a model is trained on just those columns, and the accuracy is measured.
# then repeat to find the set of PMCs that produces the highest accuracy in those models

#cross_corr is a cross correlation matrix that is a pandas dataframe
#start_col is one of the column names in the cross correlation matrix that is a string
def select_best_pmcs(cross_corr, start_col, corr_method):
    best_set = [start_col]
    correlation_threshold =  CORRELATION_THRESHOLD_PERCENTAGE*max(list(correlations[corr_method][0]['Average Correlation']))
    
    for row, val in cross_corr[start_col].iteritems():
        
        if abs(val) < CROSS_CORR_THRESHOLD and row != start_col:
            best_set.append(row)
            
            #Check to see if 'row' is highly correlated with any of the other PMCs already added
            not_correlated_with_others = True
            sub_cross_corr = df_lab[best_set].corr()
            for previous_pmc, sub_val in sub_cross_corr[row].iteritems():
                
                to_add_corr = list(correlations[corr_method][0].T[previous_pmc])[0]
                if (abs(sub_val) > CROSS_CORR_THRESHOLD or to_add_corr < correlation_threshold) and previous_pmc != row:
                    not_correlated_with_others = False
                    break
            
            if not_correlated_with_others == False:
                best_set = best_set[:-1]
                
                
            
        if len(best_set) == MAX_PMCS_TO_SELECT:
            return best_set
        
    return best_set

# %%
def find_all_sets_of_noncorrelated_pmcs(cross_corr, corr_method):    
    method_best_pmcs = {}
    for col in cross_corr.columns:
        temp_sorted = sorted(select_best_pmcs(cross_corr, col, corr_method))
    
        sum_corr = 0
        for row, val in correlations[corr_method][0]['Average Correlation'].iteritems():
            if row in temp_sorted:
                sum_corr = sum_corr + val
        avg_avg_corr = sum_corr/len(temp_sorted)
    
        if not temp_sorted in list(method_best_pmcs.keys()) and len(temp_sorted) > 1:
            method_best_pmcs[avg_avg_corr] = temp_sorted

    method_best_pmcs = {k:method_best_pmcs[k] for k in sorted(list(method_best_pmcs.keys()), reverse=1)}
    return method_best_pmcs

# %%
best_spearman_pmcs = find_all_sets_of_noncorrelated_pmcs(spear_cross_corr, 'spearman')
best_spearman_pmcs
# Out:
# {0.31353901866375616: ['41', '58', '67', '72', '84'],
#  0.3131640376710177: ['30', '41', '67', '72', '84'],
#  0.31268433742629026: ['41', '67', '69', '72', '84'],
#  0.31194628187631335: ['36', '41', '58', '67', '84'],
#  0.31119459847847486: ['41', '58', '63', '67', '84'],
#  0.31108442808734127: ['41', '57', '67', '72', '84'],
#  0.309798533053329: ['24', '41', '67', '72', '84'],
#  0.3097352711490453: ['41', '58', '67', '84', '90'],
#  0.3095297058228807: ['41', '58', '67', '81', '84'],
#  0.3078154660129246: ['29', '41', '67', '72', '84'],
#  0.30743532078310165: ['41', '45', '58', '67', '84'],
#  0.3072631795469555: ['14', '41', '67', '72', '84'],
#  0.30715501747024365: ['41', '67', '68', '72', '84'],
#  0.30711356012253843: ['41', '54', '58', '67', '84'],
#  0.3068263977386983: ['30', '41', '63', '67', '80', '84'],
#  0.3067654912354835: ['41', '63', '67', '69', '71', '84'],
#  0.306387277895777: ['41', '63', '67', '69', '84', '89'],
#  0.3062152697719154: ['28', '41', '58', '67', '84'],
#  0.30578965056554386: ['41', '67', '72', '73', '84'],
#  0.3051280544146219: ['4', '41', '67', '72', '84'],
#  0.30448625450585676: ['18', '41', '58', '67', '84'],
#  0.30434103761955833: ['26', '41', '63', '67', '69', '84'],
#  0.30360833420151107: ['27', '41', '58', '67', '84'],
#  0.3028731476721366: ['41', '58', '67', '84', '9'],
#  0.3020901919497315: ['41', '6', '67', '72', '84'],
#  0.3019995846215035: ['17', '41', '54', '67', '69', '84']}

# %%
best_pearson_pmcs = find_all_sets_of_noncorrelated_pmcs(pear_cross_corr, 'pearson')
best_pearson_pmcs
# Out:
# {0.3766577333516657: ['69', '94'],
#  0.36999150169530864: ['65', '69'],
#  0.3690472953522277: ['66', '69'],
#  0.36539404644118245: ['69', '83'],
#  0.3518596588705365: ['69', '82'],
#  0.344451041932795: ['67', '69'],
#  0.32709476541578064: ['11', '69']}

# %%
best_kendall_pmcs = find_all_sets_of_noncorrelated_pmcs(ken_cross_corr, 'kendall')
best_kendall_pmcs
# Out:
# {0.24947905973452178: ['58', '67', '72', '84'],
#  0.2489181662067454: ['30', '67', '72', '84'],
#  0.24843043270433107: ['36', '58', '67', '84'],
#  0.2472598722985368: ['67', '69', '72', '84'],
#  0.24655265872003612: ['57', '67', '72', '84'],
#  0.24626001861858754: ['58', '63', '67', '84'],
#  0.24513823156303471: ['58', '67', '84', '90'],
#  0.24506507153767254: ['58', '67', '81', '84'],
#  0.24401644450748183: ['28', '58', '67', '84'],
#  0.24106565681787545: ['14', '67', '72', '84'],
#  0.2409681101173926: ['29', '67', '72', '84'],
#  0.24035844323937472: ['24', '67', '72', '84'],
#  0.24001702978768474: ['4', '67', '72', '84'],
#  0.2389196294072526: ['67', '68', '72', '84'],
#  0.23816364247851046: ['67', '72', '73', '84'],
#  0.23511530808842124: ['6', '67', '72', '84']}

# %% [markdown]
# # Now to try HCA

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
import operator

# %%
def create_hca(corr_method):
    '''
    Here we use dataset with all trace
    '''
    plt.figure(figsize=(45, 25))
    df_pmcs = df_unlab.copy()

    corr = 1 - df_pmcs.corr(method=corr_method).abs()
    corr_condensed = shc.distance.squareform(corr)  # convert to condensed
    # orientation="right"
    z = shc.linkage(corr_condensed, method='average')
    # if orientation right, change rotation to 0
    dendrogram = shc.dendrogram(z, labels=corr.columns, orientation="right", leaf_rotation=0, leaf_font_size=10)
    #file_name = corr_method + ".png"
    #plt.savefig(file_name, dpi=300, bbox_inches='tight')
    plt.show()

# %%
def get_features_HCA(number_of_clusters, corr_method):
    corr = 1 - df_unlab.corr(method=corr_method).abs()
    corr_condensed = shc.distance.squareform(corr)  # convert to condensed
    z = shc.linkage(corr_condensed, method='average')
    tree = shc.cut_tree(z, n_clusters=number_of_clusters)

    # create list of features for each cluster
    feat_per_cluster = [[] for i in range(0, number_of_clusters)]
    # create list of correlation values with target
    feat_correlation = [[] for i in range(0, number_of_clusters)]

    # Here we wave each features in your cluster, but we need to know wich inside of cluster has more correlation with target
    for i in range(len(df_unlab.columns)):
        cluster_id = tree[i][0]  # get cluster identification
        # add the name of this pmcs in this cluster
        feat_per_cluster[cluster_id].append(df_unlab.columns[i])

    # Now we need to get the correlation
    dictionary = correlations[corr_method][0]#get_features_correlated_with_target_sorted(df_lab, corr_method)

    for i in range(number_of_clusters):
        for j in range(len(feat_per_cluster[i])):
            # How do I assign a cluster
            feat_correlation[i].append(dictionary[dictionary.keys()[0]].get(feat_per_cluster[i][j]))

    # This part correct this problem: TypeError: '>' not supported between instances of 'float' and 'NoneType'
    for i in range(number_of_clusters):
        for j in range(len(feat_per_cluster[i])-1):
            if feat_correlation[i][j] == None:
                feat_correlation[i].pop(j)
                feat_per_cluster[i].pop(j)

    #features_correlation_per_cluster = [[] for i in range(0, number_of_clusters)]
    selected_pmcs = []
    for i in range(number_of_clusters):
        result = dict(zip(feat_per_cluster[i], feat_correlation[i]))
        dic_params = sorted(result.items(), key=operator.itemgetter(1), reverse=True)
        selected_pmcs.append(dic_params[0][0])

        #features_correlation_per_cluster[i].append(sorted(result.items(), key=operator.itemgetter(1),reverse=True))
    return selected_pmcs

# %%
#create_hca('spearman')

# %%
#create_hca('pearson')

# %%
#create_hca('kendall')

# %%
best_hca_spearman = sorted(get_features_HCA(MAX_PMCS_TO_SELECT, 'spearman'))
best_hca_pearson = sorted(get_features_HCA(MAX_PMCS_TO_SELECT, 'pearson'))
best_hca_kendall = sorted(get_features_HCA(MAX_PMCS_TO_SELECT, 'kendall'))

# %% [markdown]
# ### Calculate the average of average correlations with the target(s)

# %%
best_hca_avg_corr = {}
for method in ['spearman', 'pearson', 'kendall']:
    best_hca_pmcs = sorted(get_features_HCA(MAX_PMCS_TO_SELECT, method))
    sum_corr = 0
    for row, val in correlations[method][0]['Average Correlation'].iteritems():
        if row in best_hca_pmcs:
            sum_corr = sum_corr + val
    avg_avg_corr = sum_corr/len(best_hca_pmcs)
    best_hca_avg_corr[avg_avg_corr] = (method, best_hca_pmcs)
best_hca_avg_corr
# Out:
# {0.18983503170321922: ('spearman', ['60', '64', '72', '84', '86', '92']),
#  0.19905990324004896: ('pearson', ['69', '85', '87', '89', '92', '94']),
#  0.14786549044854141: ('kendall', ['42', '58', '60', '64', '84', '92'])}

# %% [markdown]
# ### Look at how the PMCs are correlated with each other

# %% [markdown]
# #### Spearman

# %%
hca_spear_cross_corr = df_lab[best_hca_spearman].corr()
hca_spear_cross_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col0,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col1,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col2,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col3,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col4,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col5,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row5_col4,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col1{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col2,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col0{
#             background-color:  #f39577;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col3{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col4,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col5,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col0,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row5_col0{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col2{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col3{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col4{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col5,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col4{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col0{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col1{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col3{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col5{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col0,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col1,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col2,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col4,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col5,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col1{
#             background-color:  #f29274;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col2,#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row5_col2{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row5_col1{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row5_col3{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }</style><table id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >60</th>        <th class="col_heading level0 col1" >64</th>        <th class="col_heading level0 col2" >72</th>        <th class="col_heading level0 col3" >84</th>        <th class="col_heading level0 col4" >86</th>        <th class="col_heading level0 col5" >92</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077level0_row0" class="row_heading level0 row0" >60</th>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col1" class="data row0 col1" >0.646352</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col2" class="data row0 col2" >0.664450</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col3" class="data row0 col3" >-0.466058</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col4" class="data row0 col4" >0.963500</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row0_col5" class="data row0 col5" >0.960326</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077level0_row1" class="row_heading level0 row1" >64</th>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col0" class="data row1 col0" >0.646352</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col2" class="data row1 col2" >0.396972</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col3" class="data row1 col3" >-0.274899</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col4" class="data row1 col4" >0.702463</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row1_col5" class="data row1 col5" >0.699389</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077level0_row2" class="row_heading level0 row2" >72</th>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col0" class="data row2 col0" >0.664450</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col1" class="data row2 col1" >0.396972</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col3" class="data row2 col3" >-0.400020</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col4" class="data row2 col4" >0.699047</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row2_col5" class="data row2 col5" >0.694443</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077level0_row3" class="row_heading level0 row3" >84</th>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col0" class="data row3 col0" >-0.466058</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col1" class="data row3 col1" >-0.274899</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col2" class="data row3 col2" >-0.400020</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col4" class="data row3 col4" >-0.480504</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row3_col5" class="data row3 col5" >-0.474097</td>
#             </tr>
#             <tr>
#                         <th id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077level0_row4" class="row_heading level0 row4" >86</th>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col0" class="data row4 col0" >0.963500</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col1" class="data row4 col1" >0.702463</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col2" class="data row4 col2" >0.699047</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col3" class="data row4 col3" >-0.480504</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_0ae7397a_21f3_11eb_9eef_0c7a1558c077row4_col5" class="data row

# %% [markdown]
# #### Pearson

# %%
hca_pear_cross_corr = df_lab[best_hca_pearson].corr()
hca_pear_cross_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col0,#T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col1,#T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col2,#T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col3,#T_226dec66_21f3_11eb_8873_0c7a1558c077row4_col4,#T_226dec66_21f3_11eb_8873_0c7a1558c077row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col1,#T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col3,#T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col5,#T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col2,#T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col0,#T_226dec66_21f3_11eb_8873_0c7a1558c077row5_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col2{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col4{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col0{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col3{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col4{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col5{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col0{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col1{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col3{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col4{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col5{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col1{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col2{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col4{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col5{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row4_col0{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row4_col1{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row4_col2{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row4_col3{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row4_col5{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row5_col0{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row5_col1{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row5_col2{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_226dec66_21f3_11eb_8873_0c7a1558c077row5_col3{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }</style><table id="T_226dec66_21f3_11eb_8873_0c7a1558c077" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >69</th>        <th class="col_heading level0 col1" >85</th>        <th class="col_heading level0 col2" >87</th>        <th class="col_heading level0 col3" >89</th>        <th class="col_heading level0 col4" >92</th>        <th class="col_heading level0 col5" >94</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_226dec66_21f3_11eb_8873_0c7a1558c077level0_row0" class="row_heading level0 row0" >69</th>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col1" class="data row0 col1" >-0.251247</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col2" class="data row0 col2" >0.151973</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col3" class="data row0 col3" >-0.457630</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col4" class="data row0 col4" >0.234286</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row0_col5" class="data row0 col5" >-0.274162</td>
#             </tr>
#             <tr>
#                         <th id="T_226dec66_21f3_11eb_8873_0c7a1558c077level0_row1" class="row_heading level0 row1" >85</th>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col0" class="data row1 col0" >-0.251247</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col2" class="data row1 col2" >-0.022008</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col3" class="data row1 col3" >0.198687</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col4" class="data row1 col4" >0.065532</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row1_col5" class="data row1 col5" >0.159222</td>
#             </tr>
#             <tr>
#                         <th id="T_226dec66_21f3_11eb_8873_0c7a1558c077level0_row2" class="row_heading level0 row2" >87</th>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col0" class="data row2 col0" >0.151973</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col1" class="data row2 col1" >-0.022008</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col3" class="data row2 col3" >0.186073</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col4" class="data row2 col4" >0.426858</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row2_col5" class="data row2 col5" >-0.015869</td>
#             </tr>
#             <tr>
#                         <th id="T_226dec66_21f3_11eb_8873_0c7a1558c077level0_row3" class="row_heading level0 row3" >89</th>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col0" class="data row3 col0" >-0.457630</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col1" class="data row3 col1" >0.198687</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col2" class="data row3 col2" >0.186073</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col4" class="data row3 col4" >0.347813</td>
#                         <td id="T_226dec66_21f3_11eb_8873_0c7a1558c077row3_col5" class="data row3 col5" >0.169262</td>
#             </tr>
#             <tr>
#                         <th id="T_226dec66_21f3_11eb_8873_0c7a1558c077level0_row4" class="row_heading level0 row4" >92</th>
#                         <td id="T_226dec66_21f3_11eb_8873_0c

# %% [markdown]
# #### Kendall

# %%
hca_ken_cross_corr = df_lab[best_hca_kendall].corr()
hca_ken_cross_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col0,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col1,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col2,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col3,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row4_col4,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col1,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col0,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row4_col2,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row4_col3,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row4_col5,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row5_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col2{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col3{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col5{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col2{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col3{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col4{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col5{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col0{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col1{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col3{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col4{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col5,#T_38516bf3_21f3_11eb_b834_0c7a1558c077row5_col2{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col0{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col1{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col2{
#             background-color:  #f39577;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col4{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col5{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row4_col0{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row4_col1{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row5_col0{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row5_col1{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_38516bf3_21f3_11eb_b834_0c7a1558c077row5_col3{
#             background-color:  #f39475;
#             color:  #000000;
#         }</style><table id="T_38516bf3_21f3_11eb_b834_0c7a1558c077" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >42</th>        <th class="col_heading level0 col1" >58</th>        <th class="col_heading level0 col2" >60</th>        <th class="col_heading level0 col3" >64</th>        <th class="col_heading level0 col4" >84</th>        <th class="col_heading level0 col5" >92</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_38516bf3_21f3_11eb_b834_0c7a1558c077level0_row0" class="row_heading level0 row0" >42</th>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col1" class="data row0 col1" >-0.257908</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col2" class="data row0 col2" >0.183124</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col3" class="data row0 col3" >0.016744</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col4" class="data row0 col4" >-0.108570</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row0_col5" class="data row0 col5" >0.150462</td>
#             </tr>
#             <tr>
#                         <th id="T_38516bf3_21f3_11eb_b834_0c7a1558c077level0_row1" class="row_heading level0 row1" >58</th>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col0" class="data row1 col0" >-0.257908</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col2" class="data row1 col2" >0.194265</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col3" class="data row1 col3" >0.227683</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col4" class="data row1 col4" >-0.026162</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row1_col5" class="data row1 col5" >0.228863</td>
#             </tr>
#             <tr>
#                         <th id="T_38516bf3_21f3_11eb_b834_0c7a1558c077level0_row2" class="row_heading level0 row2" >60</th>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col0" class="data row2 col0" >0.183124</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col1" class="data row2 col1" >0.194265</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col3" class="data row2 col3" >0.646352</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col4" class="data row2 col4" >-0.466058</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row2_col5" class="data row2 col5" >0.960326</td>
#             </tr>
#             <tr>
#                         <th id="T_38516bf3_21f3_11eb_b834_0c7a1558c077level0_row3" class="row_heading level0 row3" >64</th>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col0" class="data row3 col0" >0.016744</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col1" class="data row3 col1" >0.227683</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col2" class="data row3 col2" >0.646352</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col4" class="data row3 col4" >-0.274899</td>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row3_col5" class="data row3 col5" >0.699389</td>
#             </tr>
#             <tr>
#                         <th id="T_38516bf3_21f3_11eb_b834_0c7a1558c077level0_row4" class="row_heading level0 row4" >84</th>
#                         <td id="T_38516bf3_21f3_11eb_b834_0c7a1558c077row4_col0" class="data row4 col0" >-0.108570</td>

# %% [markdown]
# # All candidate sets of PMCs

# %%
candidates = {}

for i in range(len(list(best_spearman_pmcs.keys()))):
    key = 'spearman-filter-'+str(i)
    candidates[key] = best_spearman_pmcs[list(best_spearman_pmcs.keys())[i]]
    
for i in range(len(list(best_pearson_pmcs.keys()))):
    key = 'pearson-filter-'+str(i)
    candidates[key] = best_pearson_pmcs[list(best_pearson_pmcs.keys())[i]]
    
for i in range(len(list(best_kendall_pmcs.keys()))):
    key = 'kendall-filter-'+str(i)
    candidates[key] = best_kendall_pmcs[list(best_kendall_pmcs.keys())[i]]
    
candidates['spearman-hca'] = best_hca_spearman
candidates['pearson-hca'] = best_hca_pearson
candidates['kendall-hca'] = best_hca_kendall

candidates
# Out:
# {'spearman-filter-0': ['41', '58', '67', '72', '84'],
#  'spearman-filter-1': ['30', '41', '67', '72', '84'],
#  'spearman-filter-2': ['41', '67', '69', '72', '84'],
#  'spearman-filter-3': ['36', '41', '58', '67', '84'],
#  'spearman-filter-4': ['41', '58', '63', '67', '84'],
#  'spearman-filter-5': ['41', '57', '67', '72', '84'],
#  'spearman-filter-6': ['24', '41', '67', '72', '84'],
#  'spearman-filter-7': ['41', '58', '67', '84', '90'],
#  'spearman-filter-8': ['41', '58', '67', '81', '84'],
#  'spearman-filter-9': ['29', '41', '67', '72', '84'],
#  'spearman-filter-10': ['41', '45', '58', '67', '84'],
#  'spearman-filter-11': ['14', '41', '67', '72', '84'],
#  'spearman-filter-12': ['41', '67', '68', '72', '84'],
#  'spearman-filter-13': ['41', '54', '58', '67', '84'],
#  'spearman-filter-14': ['30', '41', '63', '67', '80', '84'],
#  'spearman-filter-15': ['41', '63', '67', '69', '71', '84'],
#  'spearman-filter-16': ['41', '63', '67', '69', '84', '89'],
#  'spearman-filter-17': ['28', '41', '58', '67', '84'],
#  'spearman-filter-18': ['41', '67', '72', '73', '84'],
#  'spearman-filter-19': ['4', '41', '67', '72', '84'],
#  'spearman-filter-20': ['18', '41', '58', '67', '84'],
#  'spearman-filter-21': ['26', '41', '63', '67', '69', '84'],
#  'spearman-filter-22': ['27', '41', '58', '67', '84'],
#  'spearman-filter-23': ['41', '58', '67', '84', '9'],
#  'spearman-filter-24': ['41', '6', '67', '72', '84'],
#  'spearman-filter-25': ['17', '41', '54', '67', '69', '84'],
#  'pearson-filter-0': ['69', '94'],
#  'pearson-filter-1': ['65', '69'],
#  'pearson-filter-2': ['66', '69'],
#  'pearson-filter-3': ['69', '83'],
#  'pearson-filter-4': ['69', '82'],
#  'pearson-filter-5': ['67', '69'],
#  'pearson-filter-6': ['11', '69'],
#  'kendall-filter-0': ['58', '67', '72', '84'],
#  'kendall-filter-1': ['30', '67', '72', '84'],
#  'kendall-filter-2': ['36', '58', '67', '84'],
#  'kendall-filter-3': ['67', '69', '72', '84'],
#  'kendall-filter-4': ['57', '67', '72', '84'],
#  'kendall-filter-5': ['58', '63', '67', '84'],
#  'kendall-filter-6': ['58', '67', '84', '90'],
#  'kendall-filter-7': ['58', '67', '81', '84'],
#  'kendall-filter-8': ['28', '58', '67', '84'],
#  'kendall-filter-9': ['14', '67', '72', '84'],
#  'kendall-filter-10': ['29', '67', '72', '84'],
#  'kendall-filter-11': ['24', '67', '72', '84'],
#  'kendall-filter-12': ['4', '67', '72', '84'],
#  'kendall-filter-13': ['67', '68', '72', '84'],
#  'kendall-filter-14': ['67', '72', '73', '84'],
#  'kendall-filter-15': ['6', '67', '72', '84'],
#  'spearman-hca': ['60', '64', '72', '84', '86', '92'],
#  'pearson-hca': ['69', '85', '87', '89', '92', '94'],
#  'kendall-hca': ['42', '58', '60', '64', '84', '92']}
